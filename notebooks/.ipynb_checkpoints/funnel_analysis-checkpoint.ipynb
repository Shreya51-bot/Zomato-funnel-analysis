# %%
import pandas as pd
import numpy as np

np.random.seed(42)

users = 5000

data = pd.DataFrame({
    "user_id": range(1, users + 1),
    "app_open": np.random.choice([1], users),
    "restaurant_view": np.random.choice([0,1], users, p=[0.2,0.8]),
    "add_to_cart": np.random.choice([0,1], users, p=[0.4,0.6]),
    "checkout": np.random.choice([0,1], users, p=[0.5,0.5]),
    "order_complete": np.random.choice([0,1], users, p=[0.6,0.4])
})

data.head()
# Out:
#    user_id  app_open  restaurant_view  add_to_cart  checkout  order_complete
# 0        1         1                1            0         0               0
# 1        2         1                1            1         0               1
# 2        3         1                1            1         0               0
# 3        4         1                1            0         1               0
# 4        5         1                0            1         0               0
